# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
import csv
import os
import warnings
from sklearn.exceptions import ConvergenceWarning

# Suppress ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)


model_used = 'Light_GBM'

def ensure_directory_exists(filepath):
    os.makedirs(os.path.dirname(filepath), exist_ok=True)

# %%
def load_and_combine_features(modality_keys, dataset_type):
    combined_features = []
    for modality in modality_keys:
        # Load the features for each modality
        features = np.load(f'../local_spatial/features/{modality}/{dataset_type}/{dataset_type}_backbone_outputs.npy')
        combined_features.append(features)
    # Combine features along the feature dimension (axis=1)
    return np.concatenate(combined_features, axis=1)

# %%
def make_csv(y_pred_validation, modality_used):
    df = pd.read_csv('../dataset/MICCAI_BraTS2020_ValidationData/survival_evaluation.csv')
    validation_ids = df['BraTS20ID'].values
    filename = f"../LASSO_local_global_predictions/{model_used}/{modality_used}_{model_used}.csv"

    ensure_directory_exists(filename)

    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["ID", "Days"])
        for id, day in zip(validation_ids, y_pred_validation):
            writer.writerow([id, day])

    print(f"CSV file '{filename}' created successfully.")

# %%
def load_features(modality_used):
    base_dir = os.path.join('../Global_extracted_features', modality_used)
    train_features = np.load(os.path.join(base_dir, 'train_features.npy'))
    validate_features = np.load(os.path.join(base_dir, 'validate_features.npy'))
    train_labels = np.load(os.path.join(base_dir, 'train_labels.npy'))
    return train_features, validate_features, train_labels

# %%
def train_model(train_features, validate_features, train_labels, modality_used):
    scaler = StandardScaler()
    train_features_scaled = scaler.fit_transform(train_features)
    validate_features_scaled = scaler.transform(validate_features)

    # Print feature size before Lasso feature selection
    print(f"Size of features before Lasso: {train_features_scaled.shape}")

    # Lasso Feature Selection with increased regularization
    lasso = LassoCV(cv=5, random_state=42, max_iter=10000, alphas=np.logspace(-4, -0.5, 30)).fit(train_features_scaled, train_labels)
    
    # Select non-zero coefficients
    mask = lasso.coef_ != 0
    train_features_selected = train_features_scaled[:, mask]
    validate_features_selected = validate_features_scaled[:, mask]

    # Check if any features were selected
    if train_features_selected.shape[1] == 0:
        print(f"No features selected for modality {modality_used}. Skipping this combination.")
        return

    # Print feature size after Lasso feature selection
    print(f"Size of features after Lasso: {train_features_selected.shape}")

    param_dist = {
        'num_leaves': [31, 63, 127],
        'max_depth': [-1, 5, 10, 20],
        'learning_rate': [0.01, 0.05, 0.1],
        'n_estimators': [100, 200, 300],
        'min_child_samples': [10, 20, 30]
    }

    # lgb_model = lgb.LGBMRegressor(random_state=42)
    # random_search = RandomizedSearchCV(lgb_model, param_distributions=param_dist, n_iter=20, cv=5, random_state=42, n_jobs=-1)
    # random_search.fit(train_features_selected, train_labels)

    # y_pred_validation = random_search.predict(validate_features_selected)
    # make_csv(y_pred_validation, modality_used)

# %%
GBM_global = [
    "flair_t1ce",
    "flair_t1_t1ce_t2",
    "flair",
    "flair_t1ce",
    "flair_t1ce",
    "flair_t1ce_t2",
    "flair_t1ce_t2",
    "flair_t1ce_t2",
    "flair"
]
GBM_local = [
    "t2",
    "t1ce",
    "flair",
    "t1",
    "flair_t1ce",
    "flair",
    "flair_t1ce",
    "flair_t1ce_t2",
    "t1"
]

# %%
RF_global = [
    "flair_t1ce_t2",
    "flair",
    "flair_t1ce_t2",
    "flair_t1ce_t2",
    "flair",
    "flair",
    "flair",
    "flair",
    "flair_t1ce"
]
RF_local = [
    "flair_t1ce",
    "flair",
    "flair",
    "flair_t1ce_t2",
    "t1",
    "flair_t1ce",
    "flair_t1ce_t2",
    "flair_t1_t1ce_t2",
    "flair_t1_t1ce_t2"
]

# %%
XGB_global = [
    "flair",
    "flair",
    "flair_t1ce",
    "flair_t1ce",
    "flair_t1ce_t2",
    "flair_t1ce_t2",
    "flair",
    "flair_t1ce",
    "flair_t1ce"
]
XGB_local = [
    "flair",
    "flair_t1ce",
    "t2",
    "flair_t1_t1ce_t2",
    "flair",
    "t2",
    "flair_t1ce_t2",
    "flair",
    "flair_t1ce"
]

# %%
# Define modality keys
modality_keys_list_global_features = [
    ["flair"],
    # ["t1ce"],
    # ["flair", "t1ce"],
    # ["flair", "t1ce", "t2"],
    # ["flair", "t1", "t1ce", "t2"]
]

modality_keys_list_local_features = [
    ["flair"],
    # ["t1ce"],
    # ['t1'],
    # ['t2'],
    # ["flair", "t1ce"],
    # ["flair", "t1ce", "t2"],
    # ["flair", "t1", "t1ce", "t2"]
]

# %%
for modality_used_global, modality_used_local in zip(XGB_global, XGB_local):
    modality_key_local = modality_used_local.split("_")
    modality_keys_list_global_features = modality_used_global.split("_")
    print(f"\nLoading and combining features... \n local-{modality_used_local}\n global-{modality_used_global}")
    local_train_features = load_and_combine_features(modality_key_local, 'train')
    local_validation_features = load_and_combine_features(modality_key_local, 'validation')

    global_train_features, global_validate_features, train_labels = load_features(modality_used_global)

    combined_training_features = np.concatenate((global_train_features, local_train_features), axis=1)
    combined_validation_features = np.concatenate((global_validate_features, local_validation_features), axis=1)

    modality_used = 'global_' + modality_used_global + '___local_' + modality_used_local
    train_model(combined_training_features, combined_validation_features, train_labels, modality_used)
# Out:
# Loading and combining features...
#  local-flair
#  global-flair
# Size of features before Lasso: (236, 808)
# Size of features after Lasso: (236, 163)
#
# Loading and combining features...
#  local-flair_t1ce
#  global-flair
# Size of features before Lasso: (236, 872)
# Size of features after Lasso: (236, 168)
#
# Loading and combining features...
#  local-t2
#  global-flair_t1ce
# Size of features before Lasso: (236, 808)
# Size of features after Lasso: (236, 157)
#
# Loading and combining features...
#  local-flair_t1_t1ce_t2
#  global-flair_t1ce
# Size of features before Lasso: (236, 1000)
# Size of features after Lasso: (236, 166)
#
# Loading and combining features...
#  local-flair
#  global-flair_t1ce_t2
# Size of features before Lasso: (236, 808)
# Size of features after Lasso: (236, 184)
#
# Loading and combining features...
#  local-t2
#  global-flair_t1ce_t2
# Size of features before Lasso: (236, 808)
# Size of features after Lasso: (236, 186)
#
# Loading and combining features...
#  local-flair_t1ce_t2
#  global-flair
# Size of features before Lasso: (236, 936)
# Size of features after Lasso: (236, 189)
#
# Loading and combining features...
#  local-flair
#  global-flair_t1ce
# Size of features before Lasso: (236, 808)
# Size of features after Lasso: (236, 150)
#
# Loading and combining features...
#  local-flair_t1ce
#  global-flair_t1ce
# Size of features before Lasso: (236, 872)
# Size of features after Lasso: (236, 159)

# %%
 

# for modality_key_global in modality_keys_list_global_features:
#     for modality_key_local in modality_keys_list_local_features:
#         # Load the combined features
#         modality_used_local = "_".join(modality_key_local)
#         print("Loading and combining features...")
#         local_train_features = load_and_combine_features(modality_key_local, 'train')
#         local_validation_features = load_and_combine_features(modality_key_local, 'validation')

#         modality_used_global = "_".join(modality_key_global)
#         global_train_features, global_validate_features, train_labels = load_features(modality_used_global)

#         combined_training_features = np.concatenate((global_train_features, local_train_features), axis=1)
#         combined_validation_features = np.concatenate((global_validate_features, local_validation_features), axis=1)

#         modality_used = 'global_' + modality_used_global + '___local_' + modality_used_local
#         train_model(combined_training_features, combined_validation_features, train_labels, modality_used)
# Out:
# Loading and combining features...
# Size of features before Lasso: (236, 808)
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.023e+06, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.077e+06, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.973e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.166e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.305e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.443e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.124e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.770e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.228e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.409e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.873e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.522e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.086e+05, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.378e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.836e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.308e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.272e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.560e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.963e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.596e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e+04, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.953e+03, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.397e+03, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.233e+03, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.361e+03, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.367e+03, tolerance: 2.533e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.216e+06, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.031e+06, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.984e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.782e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.682e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.532e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.710e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.504e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.010e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.417e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.129e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.798e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.431e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.053e+05, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.131e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.355e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.841e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.656e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.808e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.109e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.543e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.191e+04, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.477e+03, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.363e+03, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.618e+03, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.752e+03, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.033e+03, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.809e+03, tolerance: 2.172e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.605e+06, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.119e+06, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.292e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.790e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.930e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.455e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.735e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.328e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.193e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.137e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.445e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.990e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.602e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.207e+05, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.281e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.010e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.313e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.083e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.114e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.220e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.766e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.314e+04, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.577e+03, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.349e+03, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.244e+03, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.682e+03, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.131e+03, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.665e+03, tolerance: 2.491e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.256e+06, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.941e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.614e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.251e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.948e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.307e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.951e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.225e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.691e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.446e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.062e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.708e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.304e+05, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.210e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.497e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.741e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.394e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.518e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.676e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.074e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.521e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.195e+04, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.395e+03, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.759e+03, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.788e+03, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.298e+03, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.256e+03, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.009e+03, tolerance: 2.210e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.656e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.736e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.776e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.680e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.403e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.272e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.345e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.435e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.825e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.140e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.547e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.978e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.444e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.172e+05, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.680e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.569e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.120e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.935e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.044e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.356e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.759e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.338e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.031e+04, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.679e+03, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.444e+03, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.419e+03, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.950e+03, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.874e+03, tolerance: 2.444e+03
#   model = cd_fast.enet_coordinate_descent(
# Size of features after Lasso: (236, 163)
# /home/m1/23CS60R48/anaconda3/envs/gpu/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.579e+06, tolerance: 2.964e+03
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# - Size of features before Lasso: (236, 808)
# - Size of features after Lasso: (236, 163)
